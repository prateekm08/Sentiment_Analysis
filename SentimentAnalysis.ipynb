# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.autograd import Variable

import pandas as pd
import torch.nn.functional as F

# %%
df = pd.read_csv('Tweets.csv')

#visualise the data
df.head(5)
# Out:
#              tweet_id airline_sentiment  airline_sentiment_confidence  \
# 0  570306133677760513           neutral                        1.0000
# 1  570301130888122368          positive                        0.3486
# 2  570301083672813571           neutral                        0.6837
# 3  570301031407624196          negative                        1.0000
# 4  570300817074462722          negative                        1.0000
#
#   negativereason  negativereason_confidence         airline  \
# 0            NaN                        NaN  Virgin America
# 1            NaN                     0.0000  Virgin America
# 2            NaN                        NaN  Virgin America
# 3     Bad Flight                     0.7033  Virgin America
# 4     Can't Tell                     1.0000  Virgin America
#
#   airline_sentiment_gold        name negativereason_gold  retweet_count  \
# 0                    NaN     cairdin                 NaN              0
# 1                    NaN    jnardino                 NaN              0
# 2                    NaN  yvonnalynn                 NaN              0
# 3                    NaN    jnardino                 NaN              0
# 4                    NaN    jnardino                 NaN              0
#
#                                                 text tweet_coord  \
# 0                @VirginAmerica What @dhepburn said.         NaN
# 1  @VirginAmerica plus you've added commercials t...         NaN
# 2  @VirginAmerica I didn't today... Must mean I n...         NaN
# 3  @VirginAmerica it's really aggressive to blast...         NaN
# 4  @VirginAmerica and it's a really big bad thing...         NaN
#
#                tweet_created tweet_location               user_timezone
# 0  2015-02-24 11:35:52 -0800            NaN  Eastern Time (US & Canada)
# 1  2015-02-24 11:15:59 -0800            NaN  Pacific Time (US & Canada)
# 2  2015-02-24 11:15:48 -0800      Lets Play  Central Time (US & Canada)
# 3  2015-02-24 11:15:36 -0800            NaN  Pacific Time (US & Canada)
# 4  2015-02-24 11:14:45 -0800            NaN  Pacific Time (US & Canada)

# %%
sent_to_ix = {'negative':0, 'neutral':1, 'positive': 2}
ix_to_sent = { 0:'negative', 1:'neutral', 2:'positive'}

df['text'] = df['text'].apply(lambda sentence: sentence.replace("!", " ! "))
df['text'] = df['text'].apply(lambda sentence: sentence.replace("%", " % "))
df['text'] = df['text'].apply(lambda sentence: sentence.replace("^", " ^ "))
df['text'] = df['text'].apply(lambda sentence: sentence.replace("/", " / "))
df['text'] = df['text'].apply(lambda sentence: sentence.replace("#", " # "))
df['text'] = df['text'].apply(lambda sentence: sentence.replace(":", " : "))
df['text'] = df['text'].apply(lambda sentence: sentence.replace(";", " ; "))
df['text'] = df['text'].apply(lambda sentence: sentence.replace(".", " . "))
df['text'] = df['text'].apply(lambda sentence: sentence.replace(",", " , "))
df['text'] = df['text'].apply(lambda sentence: sentence.replace("@", " @ "))
df['text'] = df['text'].apply(lambda sentence: sentence.replace("?", " ? "))
df['text'] = df['text'].apply(lambda sentence: sentence.replace("'", " ' "))
df['text'] = df['text'].apply(lambda sentence: sentence.lower().split())
df['airline_sentiment'] = df['airline_sentiment'].apply(lambda sent: sent_to_ix[sent])

#visualise again
df.head(5)
# Out:
#              tweet_id  airline_sentiment  airline_sentiment_confidence  \
# 0  570306133677760513                  1                        1.0000
# 1  570301130888122368                  2                        0.3486
# 2  570301083672813571                  1                        0.6837
# 3  570301031407624196                  0                        1.0000
# 4  570300817074462722                  0                        1.0000
#
#   negativereason  negativereason_confidence         airline  \
# 0            NaN                        NaN  Virgin America
# 1            NaN                     0.0000  Virgin America
# 2            NaN                        NaN  Virgin America
# 3     Bad Flight                     0.7033  Virgin America
# 4     Can't Tell                     1.0000  Virgin America
#
#   airline_sentiment_gold        name negativereason_gold  retweet_count  \
# 0                    NaN     cairdin                 NaN              0
# 1                    NaN    jnardino                 NaN              0
# 2                    NaN  yvonnalynn                 NaN              0
# 3                    NaN    jnardino                 NaN              0
# 4                    NaN    jnardino                 NaN              0
#
#                                                 text tweet_coord  \
# 0     [@, virginamerica, what, @, dhepburn, said, .]         NaN
# 1  [@, virginamerica, plus, you, ', ve, added, co...         NaN
# 2  [@, virginamerica, i, didn, ', t, today, ., .,...         NaN
# 3  [@, virginamerica, it, ', s, really, aggressiv...         NaN
# 4  [@, virginamerica, and, it, ', s, a, really, b...         NaN
#
#                tweet_created tweet_location               user_timezone
# 0  2015-02-24 11:35:52 -0800            NaN  Eastern Time (US & Canada)
# 1  2015-02-24 11:15:59 -0800            NaN  Pacific Time (US & Canada)
# 2  2015-02-24 11:15:48 -0800      Lets Play  Central Time (US & Canada)
# 3  2015-02-24 11:15:36 -0800            NaN  Pacific Time (US & Canada)
# 4  2015-02-24 11:14:45 -0800            NaN  Pacific Time (US & Canada)

# %%
vocab = {}
N_df = len(df)

for i in xrange(N_df):
    for word in df['text'][i]:
        if word not in vocab:
            vocab[word] = len(vocab)
            
vocab_size = len(vocab)
print 'Total distinct words: {}'.format(vocab_size)
print 'Created dictionary: '
print vocab
# Out:
# Total distinct words: 17209
# Created dictionary:
# {'xaizw2isml': 5758, 'twetpxuppn': 15661, 'cussed': 15092, 'gaincustomers': 8474, 'h44uj63cjg': 8438, 'vn3jjia53o': 9026, 'apnea': 11681, 'four': 596, 'jparkermastin': 8799, '3a\xe2\x9e\xa1\xef\xb8\x8f8c': 17032, 'hsv': 15291, 'sw\xe2\x80\x9dfollowed': 10298, 'will1531': 3742, 'hanging': 4152, 'woody': 17088, 'comically': 3001, 'localized': 2431, 'looking': 1143, 'jgdu5us8dz': 10815, 'granting': 4439, 'eligible': 10181, 'snowing': 10659, 'etfjqiwuvt)': 14803, 'unanswered': 4323, 'refunding': 1295, 'caned': 4147, 'qgwk10dewv': 6221, 'upaz1ef3dl': 16611, 'demoted': 3223, 'lord': 11061, 'bduauzfhw2': 12692, 'pafe': 15411, 'saipan': 2573, 'inclement': 9543, '0hmmqczkcf': 10587, '(continued)': 2340, 'deli': 11514, '9tbsjquw41': 5922, 'regional': 6387, '5-minute': 8304, 'ritacomo': 7855, 'appropriation': 11136, 'mavigetbbw': 10235, 'yellow': 13221, 'werin': 1266, 'cng': 9850, 'screaming': 4637, 'frghglmkqf': 9117, 'pasengers': 961, 'disturb': 12006, 'basics': 16365, 'internally': 16738, 'prize': 3708, 'betch': 9487, 'xgfs6tjtmo': 11703, 'bugging': 12372, 'e0c9bi09cf': 5720, 'wednesday': 6253, '"music"': 9810, 'dawn': 16437, 'izfofgjzui\xe2\x80\x9d': 11066, 'commented': 5363, 'charter': 11276, 'expanded': 11644, '(except': 5676, '))\xe2\x9d\xa4\xef\xb8\x8f': 8510, 'her-': 13223, 'tired': 2701, 'evennotified': 8545, 'her"': 15598, 'lgbt': 9049, 'ufyxxkisa3': 11849, 'complainers': 14655, '"paperwork': 16227, 'pulse': 9424, 'scheming': 14825, 'second': 108, '276': 808, '277': 12165, 'kconti44': 16792, 'shrugging': 4892, 'sailed': 7519, '3487': 15901, 'feck': 8124, 'supvsr': 9449, 'diufep8n2q': 5307, '87yearslate': 10236, 'errors': 1343, 't-minus': 1872, 'e+': 7544, 'forgetting': 7001, 'fingers': 2409, 'ftmyers': 8713, 'bonuses': 1987, 'charac': 13271, '(domestic)': 16263, 'replying-i': 11572, 'increasing': 7561, 'sales"': 9931, 'admiral': 6866, 'blackhistorymonth': 9229, 'report"': 11386, '27a': 5097, 'superyan': 15623, '27d': 3021, '1651': 16062, 'truebluecolors': 11669, 'u1vieuidf5': 6085, 'herb': 10128, 'top-flight': 14226, 'canadaair': 6409, '27l': 5580, 'here': 642, '\xe2\x9d\xa4\xef\xb8\x8f': 190, '\xf0\x9f\x98\x91\xe2\x80\x9c': 11139, 'china': 2583, 'answer-': 16469, 'waltdisneyworld': 867, 'dorm': 12624, 'affiliated': 7536, 'dallas_news': 985, 'aa4285': 15532, 'conversational': 5548, 'argh': 12824, 'kids': 900, 'alwaysdelayedonunited': 3278, 'soul': 9585, 'k': 2448, 'auf': 13447, '"why': 7651, 'typically': 5950, 'reports': 2987, 'at\xf0\x9f\x98\xb3': 13854, '1212': 3330, 'error"': 10422, 'lmk': 16377, 'menu': 6975, 'chking': 15701, 'auh': 15757, '\xe2\x9c\x94\xef\xb8\x8f': 5211, 'military': 2271, 'pullin': 14210, 'spotty': 4265, 'brownsville': 16032, 'pairings': 944, 'criticism': 10014, 'appropriately': 5668, 'icecream': 14023, 'magically': 8282, 'ground': 2183, '9c': 6514, 'explained': 4823, 'replace': 4505, 'brought': 1446, '9+hours': 6714, 'xx2m2jxqep': 10855, '1stclass': 3159, 'nightmarish': 14533, '(+restr)': 1038, 'txt': 10418, 'weaktea': 6043, 'lnded': 16991, 'spoke': 1573, 'flcnnn2usd': 5244, 'px8hqoks3r': 607, 'schiphol': 6958, 'dispatcher': 7114, 'skycap': 16272, 'dnt': 8698, 'music': 677, 'therefore': 6280, 'passport': 4804, 'strike': 5438, 'argg': 15670, 'until': 512, 'inpolite': 4500, 'expiring': 6312, 'hury': 16684, 'paperwork': 1499, 'holz': 14871, 'holy': 8029, 'relax': 9187, 'successful': 15869, 'brings': 13375, '160': 15997, '"case': 14602, 'agent-booked': 15881, '20th': 13835, 'hurt': 4209, '99': 5877, 'glass': 11300, 'flights\xf0\x9f\x98\x94': 10513, '90': 2020, '964012': 2838, 'hold': 496, '95': 16788, 'adam_karren': 6547, 'circumstances': 4234, 'nofood': 13774, 'locked': 7728, 'marathon': 11907, 'blade': 11026, 'bleh': 15769, 'description': 11643, 'daaa0rqbxw': 5995, '"planned': 13153, 'example': 3131, 'taxi-ing': 13181, 'deltapoints': 10369, 'mjkpgvxmpc': 2551, 'owes': 13419, '1217': 14859, '70plus': 10264, 'organized': 16647, 'digit': 14317, 'frown': 12090, 'dragons': 9015, 'nrosenb1': 15862, 'flight4592' ...

# %%
dtype = torch.FloatTensor
dtype_long = torch.LongTensor

if torch.cuda.is_available():
    print 'Cuda is available'
    dtype = torch.cuda.FloatTensor
    dtype_long = torch.cuda.LongTensor
# Out:
# Cuda is available

# %%
def prepare_sequence(sentence, vocab):
    ixs = []
    for word in sentence:
        if word not in vocab:
            sentence.remove(word)
    ixs = map(lambda word: vocab[word], sentence)
    ixs_var = Variable(dtype_long(ixs))        
    return ixs_var

#Let's test it out
sentence = 'hello sneha'.split()
print sentence
print 'Code for the above sentence is'
print prepare_sequence(sentence, vocab)
# Out:
# ['hello', 'sneha']
# Code for the above sentence is
# Variable containing:
#  5072
# [torch.cuda.LongTensor of size 1 (GPU 0)]

# %%
print len(df)

df_train = df[:14000]
df_val = df[14000:]
# Out:
# 14640

# %%
class LSTMClassifier(nn.Module):
    
    def __init__(self, vocab_size, embedded_dim, hidden_dim):
        super(LSTMClassifier, self).__init__()
        
        self.embed = nn.Embedding(vocab_size, embedded_dim)
        self.lstm = nn.LSTM(embedded_dim, hidden_dim, 1)
        self.linear = nn.Linear(hidden_dim, 3)
        self.soft = nn.Softmax()
        
    def forward(self, input):
        embedded_sentence = self.embed(input).view((len(input), 1, embedded_dim))
        _, out = self.lstm(embedded_sentence)
        out = out[-1]
        out  = F.relu(out.view((1, -1)))
        out = self.linear(out)
        return self.soft(out)

# %%
N_epochs = 15
embedded_dim = 10
hidden_dim = 10

model = LSTMClassifier(vocab_size, embedded_dim, hidden_dim).type(dtype)
loss_fn = nn.CrossEntropyLoss().type(dtype)
optimizer = optim.Adam(model.parameters())

# %%
N_train = len(df_train)
N_val = len(df_val)
N_epochs = 15

for epoch in xrange(N_epochs):
    train_epoch_loss = 0
    val_epoch_loss = 0
    for i in xrange(N_train):
        model.train()
        sentence, sentiment = df_train['text'][i], df_train['airline_sentiment'][i]
        
        sentence_var = prepare_sequence(sentence, vocab)
        scores = model(sentence_var)
        loss = loss_fn(scores, Variable(dtype_long([sentiment])))   
        train_epoch_loss += loss.data[0]
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    
    print 'Training Loss for epoch {} is {}'.format(epoch, train_epoch_loss)
    
    for i in xrange(N_val):
        model.eval()
        sentence, author = df_val['text'][14000 + i], df_val['airline_sentiment'][14000 + i]
        
        sentence_var = prepare_sequence(sentence, vocab)
        scores = model(sentence_var)
        loss = loss_fn(scores, Variable(dtype_long([author])))   
        val_epoch_loss += loss.data[0]
        
    print 'Validation Loss for epoch {} is {}'.format(epoch, val_epoch_loss)
# Out:
# Training Loss for epoch 0 is 12303.2538344
# Validation Loss for epoch 0 is 479.991138399
# Training Loss for epoch 1 is 11573.0011764
# Validation Loss for epoch 1 is 471.557220817
# Training Loss for epoch 2 is 11010.9647085
# Validation Loss for epoch 2 is 470.25041616
# Training Loss for epoch 3 is 10603.9650126
# Validation Loss for epoch 3 is 456.01934725
# Training Loss for epoch 4 is 10302.4494565
# Validation Loss for epoch 4 is 453.122085154
# Training Loss for epoch 5 is 10079.9606791
# Validation Loss for epoch 5 is 451.631572306
# Training Loss for epoch 6 is 9858.55616796
# Validation Loss for epoch 6 is 447.503376782
# Training Loss for epoch 7 is 9699.27742261
# Validation Loss for epoch 7 is 454.562984109
# Training Loss for epoch 8 is 9537.40374041
# Validation Loss for epoch 8 is 446.742719948
# Training Loss for epoch 9 is 9408.97753096
# Validation Loss for epoch 9 is 446.117323399
# Training Loss for epoch 10 is 9302.04875076
# Validation Loss for epoch 10 is 448.315862298
# Training Loss for epoch 11 is 9188.93769586
# Validation Loss for epoch 11 is 466.899404883
# Training Loss for epoch 12 is 9110.57840014
# Validation Loss for epoch 12 is 457.586709261
# Training Loss for epoch 13 is 9021.68422329
# Validation Loss for epoch 13 is 461.552628696
# Training Loss for epoch 14 is 8980.38343042
# Validation Loss for epoch 14 is 448.898519993

# %%
def test_sentence(sentence):
    sentence_var = prepare_sequence(sentence, vocab)
    scores = model(sentence_var)
    ix = torch.max(scores, 1)[1].data.cpu().numpy()[0][0]
    sentiment = ix_to_sent[ix]
    return sentiment

sentiment = test_sentence("I had a very good flight ! Very courteous staff .".lower().split())
print 'Beep bop; tickety dop; I think that sentence is {}'.format(sentiment)
# Out:
# Beep bop; tickety dop; I think that sentence is positive

# %%
PATH = 'saved_model.pth'

# %%
#Save the model
torch.save(model.state_dict(), PATH)

# %%
#Load
model = LSTMClassifier(vocab_size, embedded_dim, hidden_dim).type(dtype)
model.load_state_dict(torch.load(PATH))
